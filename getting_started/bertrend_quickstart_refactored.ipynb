# %% [markdown]
# # **BERTrend Quickstart**
#
# *A production-grade tutorial notebook*
#
# **Maintainers:** L7 Execution Team
# **Last updated:** May 15, 2025
#
# ---
#
# > **Note**
# > This notebook follows the research engineering style guide used by teams at Google DeepMind and Meta FAIR.
# > - Reproducible: fixed seeds, explicit environment setup
# > - Modular: core logic moved into library abstractions
# > - Transparent: every section spells out inputs ➔ transforms ➔ outputs
# > - Lightweight: minimal boilerplate, no silent state

# %% [markdown]
# ## Table of Contents
# 1. [Environment & Dependencies](#env)
# 2. [Data Pipeline](#data)
# 3. [Model Configuration](#model)
# 4. [Trend Analysis](#analysis)
# 5. [Evaluation & Visualization](#eval)
# 6. [Next Steps & References](#next)

# %% [markdown]
# ## 1. Environment & Dependencies <a id='env'></a>
# Set up deterministic runtime and install external packages.

# %%
# Reproducibility
# import random, os, numpy as np
# SEED = 42
# random.seed(SEED)
# np.random.seed(SEED)
# os.environ['PYTHONHASHSEED'] = str(SEED)

# Dependency installation (skipped if already installed)
# Note: Comment this cell out in production/cloud runners that handle packaging.
# %pip install -qU bertrend[all] loguru pandas ipywidgets --no-warn-script-location

# %% [markdown]
# # BERTrend quickstart
# The purpose of this notebook is to complement the existing demos available in the directory `bertrend/demos` with some code examples that explain how to integrate BERTrend with your application code.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## BERTrend installation

# %%
from pathlib import Path
import pandas as pd
from pandas import Timestamp
from IPython.display import display
from loguru import logger
import os

from bertrend import DATA_PATH
from bertrend.BERTrend import BERTrend
from bertrend import MODELS_DIR
from bertrend.utils.data_loading import load_data, split_data, TEXT_COLUMN
from bertrend.services.embedding_service import EmbeddingService
from bertrend.BERTopicModel import BERTopicModel
from bertrend.topic_analysis.topic_description import generate_topic_description
from bertrend.trend_analysis.weak_signals import analyze_signal

# %%
#!pip install bertrend

# %% [markdown]
# ### Configuration of topic models

# %%
# Topic model with default parameters - each parameter of BERTopic can be modified from the constructor or can be read from a configuration file
# overrides the default config to use English
config = '''
# Default configuration file to be used for topic model

# Global parameters
[global]
language = "English"

# BERTopic parameters: https://maartengr.github.io/BERTopic/api/bertopic.html#bertopic._bertopic.BERTopic.__init__
[bertopic_model]
top_n_words = 10
verbose = true
representation_model = ["MaximalMarginalRelevance"] # KeyBERTInspired, OpenAI
zeroshot_topic_list = []
zeroshot_min_similarity = 0

# UMAP parameters: https://umap-learn.readthedocs.io/en/latest/api.html
[umap_model]
n_neighbors = 5
n_components = 5
min_dist = 0.0
metric = "cosine"
random_state = 42

# HDBSCAN parameters: https://hdbscan.readthedocs.io/en/latest/api.html
[hdbscan_model]
min_cluster_size = 5
min_samples = 5
metric = "euclidean"
cluster_selection_method = "eom"
prediction_data = true

# CountVectorizer: https://scikit-learn.org/1.5/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html
[vectorizer_model]
ngram_range = [1, 1]
stop_words = true # If true, will check `language` parameter and load associated stopwords file
min_df = 2

# ClassTfidfTransformer: https://maartengr.github.io/BERTopic/api/ctfidf.html
[ctfidf_model]
bm25_weighting = false
reduce_frequent_words = true

# MaximalMarginalRelevance: https://maartengr.github.io/BERTopic/api/representation/mmr.html
[mmr_model]
diversity = 0.3

# Reduce outliers: https://maartengr.github.io/BERTopic/api/bertopic.html#bertopic._bertopic.BERTopic.reduce_outliers
[reduce_outliers]
strategy = "c-tf-idf"
'''

topic_model = BERTopicModel(config)

# %%
# The TopicModel class is mainly a wrapper around BERTopic and can be used as-is, for example for a first analysis of data (without considering evolving trends, but this is not mandatory at all)

# %% [markdown]
# ## Using BERTrend for retrospective analysis

# %% [markdown]
# ### Instantiation of BERTrend

# %% [markdown]
# In the case of a **retrospective trend analysis** task, the goal is to identify and evaluate patterns or changes over time within a dataset, allowing for insights into historical performance, behaviors, or events that can inform future decision-making and strategy development.
#
# In this context, the general principle consists in splitting the past data into different time slices. Then each dataset is used to train a separate topic models. Each topic model description corresponding to the older data slice is merged with the next one and decay factors are applied. This allows to have a vision of topic evolution over time

# %%
# Basic creation of the object and parametrization
# BERTrend uses several topic models; therefore, it is necessary to pass a topic_model object as a reference
bertrend = BERTrend(topic_model=topic_model)

# %% [markdown]
# ### 1. Gather historical data to be analyzed

# %%
# Here some Trump tweets from: https://github.com/MarkHershey/CompleteTrumpTweetsArchive/blob/master/data/realDonaldTrump_in_office.csv
# !wget "https://raw.githubusercontent.com/MarkHershey/CompleteTrumpTweetsArchive/refs/heads/master/data/realDonaldTrump_in_office.csv"
df = pd.read_csv("../data/bertopic/trump_tweets.csv",  sep=',',quotechar='"', skipinitialspace=True)
# BERTrend expects specific data format
df = df.rename(columns={'Time': 'timestamp', 'Tweet URL': 'url', "Tweet Text": "text"})

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'id', 'text', 'isRetweet', 'isDeleted', 'device', 'favorites', 'retweets', 'timestamp', 'isFlagged']

# %%
df = (
    df                   # <- start with your frame
    .drop(columns=["Unnamed: 0"])              # optional: tidy up
    .rename(columns={"id": "ID"})              # give it the name your old code expects
)

df["source"] = df["ID"]                        # 1️⃣ identifier for source
df["url"] = "https://twitter.com/i/web/status/" + df["ID"].astype(str)  # 2️⃣ tweet URL
df["document_id"] = df.index                   # 3️⃣ unique document id

df.reset_index(inplace=True, drop=True)
df.head(5)
# Out:
#                     ID                                               text  \
# 0    98454970654916608  republicans and democrats have both created ou...
# 1  1234653427789070336  i was thrilled to be back in the great city of...
# 2  1304875170860015617  the unsolicited mail in ballot scam is a major...
# 3  1223640662689689602             getting a little exercise this morning
# 4  1215247978966986752                                    thank you elise
#
#   isRetweet isDeleted              device  favorites  retweets  \
# 0         f         f           TweetDeck         49       255
# 1         f         f  Twitter for iPhone      73748     17404
# 2         f         f  Twitter for iPhone      80527     23502
# 3         f         f  Twitter for iPhone     285863     30209
# 4         f         f  Twitter for iPhone      48510     11608
#
#              timestamp isFlagged               source  \
# 0  2011-08-02 18:07:48         f    98454970654916608
# 1  2020-03-03 01:34:50         f  1234653427789070336
# 2  2020-09-12 20:10:58         f  1304875170860015617
# 3  2020-02-01 16:14:02         f  1223640662689689602
# 4  2020-01-09 12:24:31         f  1215247978966986752
#
#                                                  url  document_id
# 0  https://twitter.com/i/web/status/9845497065491...            0
# 1  https://twitter.com/i/web/status/1234653427789...            1
# 2  https://twitter.com/i/web/status/1304875170860...            2
# 3  https://twitter.com/i/web/status/1223640662689...            3
# 4  https://twitter.com/i/web/status/1215247978966...            4

# %%
df.index
# Out:
# RangeIndex(start=0, stop=45355, step=1)

# %%
# Selection of a subset of data
df = df.head(1000)

# %% [markdown]
# ### 2. Embed data

# %%
client_secret = "bd76aa472dd91aed4a56bf1935dbb802583c119824380d8567086579c0ef3324"

# --- 1. Patch the two discovery methods ---------------------------------
from bertrend.services import embedding_client              # <-- import *module*, not just the class
EmbeddingAPIClient = embedding_client.EmbeddingAPIClient    # handy alias

def _lmstudio_model_name(self):
    # return whatever model LM Studio has loaded
    return "text-embedding-multilingual-e5-large-instruct"

def _lmstudio_num_workers(self):
    # LM Studio answers requests serially, so 1 is fine
    return 1

EmbeddingAPIClient.get_api_model_name = _lmstudio_model_name
EmbeddingAPIClient.get_num_workers    = _lmstudio_num_workers


# --- 2. Configure and build the service (NO num_workers kwarg) ----------
embedding_service = EmbeddingService(
    local=False,
    url="http://127.0.0.1:1234",
    model_name="text-embedding-multilingual-e5-large-instruct",
)

embeddings, *_ = embedding_service.embed(texts=df["text"])
print(len(embeddings), "embeddings OK ✔︎")

# --- 3. Use it -----------------------------------------------------------
embeddings, token_strings, token_embeddings = embedding_service.embed(texts=df["text"])
# Out:
# 2025-05-15 10:57:47.303 | DEBUG    | bertrend.services.embedding_client:__init__:47 - EmbeddingAPIClient(model_name='text-embedding-multilingual-e5-large-instruct', num_workers=4)
# 2025-05-15 10:57:47.303 | DEBUG    | bertrend.services.embedding_service:_remote_embed_documents:260 - Computing embeddings...
# 2025-05-15 10:57:47.304 | DEBUG    | bertrend.services.embedding_client:embed_documents:118 - Calling EmbeddingAPI using model: text-embedding-multilingual-e5-large-instruct
# 2025-05-15 10:57:47.304 | DEBUG    | bertrend.services.embedding_client:embed_documents:122 - Computing embeddings on 1000 documents using (1) batches...
# 2025-05-15 10:58:06.977 | DEBUG    | bertrend.services.embedding_service:_remote_embed_documents:260 - Computing embeddings...
# 2025-05-15 10:58:06.979 | DEBUG    | bertrend.services.embedding_client:embed_documents:118 - Calling EmbeddingAPI using model: text-embedding-multilingual-e5-large-instruct
# 2025-05-15 10:58:06.979 | DEBUG    | bertrend.services.embedding_client:embed_documents:122 - Computing embeddings on 1000 documents using (1) batches...
# 1000 embeddings OK ✔︎

# %%
from bertrend.services.embedding_client import EmbeddingAPIClient
client = EmbeddingAPIClient("http://127.0.0.1:1234", "text-embedding-multilingual-e5-large-instruct")
vecs = client.embed_documents(["alpha", "beta", "gamma"])
print(len(vecs), "vectors OK")
# Out:
# 2025-05-15 10:58:26.362 | DEBUG    | bertrend.services.embedding_client:__init__:47 - EmbeddingAPIClient(model_name='text-embedding-multilingual-e5-large-instruct', num_workers=4)
# 2025-05-15 10:58:26.363 | DEBUG    | bertrend.services.embedding_client:embed_documents:118 - Calling EmbeddingAPI using model: text-embedding-multilingual-e5-large-instruct
# 2025-05-15 10:58:26.363 | DEBUG    | bertrend.services.embedding_client:embed_documents:122 - Computing embeddings on 3 documents using (1) batches...
# 3 vectors OK

# %%
from bertrend.services.embedding_client import EmbeddingAPIClient
client = EmbeddingAPIClient("http://127.0.0.1:1234", "text-embedding-multilingual-e5-large-instruct")

# single-thread call
print(client.embed_documents(["one", "two"]))

# process backend call (if you chose option B)
from joblib import Parallel, delayed
Parallel(n_jobs=2)(delayed(client.embed_query)(w) for w in ["a", "b"])
# Out:
# 2025-05-15 10:58:26.466 | DEBUG    | bertrend.services.embedding_client:__init__:47 - EmbeddingAPIClient(model_name='text-embedding-multilingual-e5-large-instruct', num_workers=4)
# 2025-05-15 10:58:26.466 | DEBUG    | bertrend.services.embedding_client:embed_documents:118 - Calling EmbeddingAPI using model: text-embedding-multilingual-e5-large-instruct
# 2025-05-15 10:58:26.467 | DEBUG    | bertrend.services.embedding_client:embed_documents:122 - Computing embeddings on 2 documents using (1) batches...
# [[0.031277354806661606, 0.028524504974484444, -0.015595190227031708, -0.04368218779563904, 0.0369592122733593, -0.013832852244377136, -0.021443113684654236, 0.03751099109649658, 0.021532313898205757, 0.004257784225046635, 0.01270811166614294, 0.015347524546086788, -0.034358084201812744, -0.0548693910241127, -0.01980174519121647, -0.0031611984595656395, -0.04226542264223099, 0.037496019154787064, -0.008301157504320145, -0.018491435796022415, 0.0360943004488945, -0.022913865745067596, -0.013002855703234673, -0.02607542835175991, -0.011996625922620296, -0.01739376410841942, -0.04435330629348755, -0.026390645653009415, -0.0436667837202549, -0.013716107234358788, -0.011975608766078949, 0.0066103204153478146, -0.021024072542786598, -0.035917554050683975, -0.01222591008991003, 0.04862847551703453, 0.02605169080197811, -0.002091614995151758, -0.03242215886712074, 0.03574516251683235, -0.011802379041910172, 0.04569680243730545, 0.03131585940718651, -0.05859864130616188, -0.025941461324691772, 0.05042876675724983, 0.01133938692510128, -0.012447161599993706, 0.0022944032680243254, 0.025988996028900146, 0.01698199100792408, 0.016611577942967415, -0.009052756242454052, -0.028702860698103905, -0.03814048320055008, 0.024721303954720497, -0.03516223654150963, 0.012596714310348034, -0.04902372136712074, -0.001674613798968494, -0.054633185267448425, 0.005748280324041843, 0.032204195857048035, -0.04529879614710808, -0.037447281181812286, 0.04656452313065529, 0.051510006189346313, 0.022670984268188477, -0.019409745931625366, 0.012200639583170414, -0.02401081472635269, 0.024079617112874985, -0.01638776622712612, -0.013569640927016735, -0.020983273163437843, -0.004003215115517378, 0.03421544283628464, -0.0017695423448458314, 0.009033488109707832, -0.0268667284399271, 0.0940508171916008, 0.03703128173947334, -0.017151417210698128, -0.034271638840436935, 0.026215266436338425, 0.027814069762825966, 0.04483107849955559, 0.027581004425883293, 0.04227056726813316, 0.036050643771886826, -0.030330730602145195, 0.07068538665771484, 0.022952916100621223, -0.02877463772892952, -0.007972444407641888, -0.04508513584733009, 0.0016861711628735065, 0.03403015062212944, -0.011928903870284557, -0.035803645849227905, -0.06075049564242363, -0.026862410828471184, 0.013047490268945694, -0.02157716639339924, -0.02655835822224617, 0.030514290556311607, 0.026288794353
# [<class 'bertrend.services.embedding_client.EmbeddingAPIClient'>, <class 'langchain_core.embeddings.embeddings.Embeddings'>, <class 'abc.ABC'>, <class 'object'>]

# %% [markdown]
# ### 3. Split the data into time slices
#
# This can be done manually for some reason or can be done automatically based on a specified time granularity

# %%
from bertrend.utils.data_loading import group_by_days, load_data

day_granularity = 30
grouped_data = group_by_days(df=df, day_granularity=day_granularity)

# %%
# Number of sliced data
len(grouped_data)
# Out:
# 115

# %%
for p, g in grouped_data.items():
    sz = len(g)
    if sz < 3:
        print(f"{p}: {sz} doc → will skip")
    elif sz <= 6:
        print(f"{p}: {sz} doc → will down-tune UMAP (comp={min(5, sz-2)})")
# Out:
# 2011-08-02 00:00:00: 1 doc → will skip
# 2011-09-01 00:00:00: 0 doc → will skip
# 2011-10-01 00:00:00: 0 doc → will skip
# 2011-10-31 00:00:00: 0 doc → will skip
# 2011-11-30 00:00:00: 0 doc → will skip
# 2011-12-30 00:00:00: 0 doc → will skip
# 2012-01-29 00:00:00: 0 doc → will skip
# 2012-02-28 00:00:00: 0 doc → will skip
# 2012-03-29 00:00:00: 0 doc → will skip
# 2012-04-28 00:00:00: 0 doc → will skip
# 2012-05-28 00:00:00: 0 doc → will skip
# 2012-06-27 00:00:00: 0 doc → will skip
# 2012-07-27 00:00:00: 0 doc → will skip
# 2012-08-26 00:00:00: 0 doc → will skip
# 2012-09-25 00:00:00: 0 doc → will skip
# 2012-10-25 00:00:00: 2 doc → will skip
# 2012-11-24 00:00:00: 4 doc → will down-tune UMAP (comp=2)
# 2012-12-24 00:00:00: 1 doc → will skip
# 2013-01-23 00:00:00: 1 doc → will skip
# 2013-02-22 00:00:00: 0 doc → will skip
# 2013-03-24 00:00:00: 0 doc → will skip
# 2013-04-23 00:00:00: 1 doc → will skip
# 2013-05-23 00:00:00: 0 doc → will skip
# 2013-06-22 00:00:00: 0 doc → will skip
# 2013-07-22 00:00:00: 0 doc → will skip
# 2013-08-21 00:00:00: 0 doc → will skip
# 2013-09-20 00:00:00: 2 doc → will skip
# 2013-10-20 00:00:00: 1 doc → will skip
# 2013-11-19 00:00:00: 0 doc → will skip
# 2013-12-19 00:00:00: 0 doc → will skip
# 2014-01-18 00:00:00: 0 doc → will skip
# 2014-02-17 00:00:00: 0 doc → will skip
# 2014-03-19 00:00:00: 0 doc → will skip
# 2014-04-18 00:00:00: 0 doc → will skip
# 2014-05-18 00:00:00: 0 doc → will skip
# 2014-06-17 00:00:00: 0 doc → will skip
# 2014-07-17 00:00:00: 0 doc → will skip
# 2014-08-16 00:00:00: 0 doc → will skip
# 2014-09-15 00:00:00: 0 doc → will skip
# 2014-10-15 00:00:00: 0 doc → will skip
# 2014-11-14 00:00:00: 0 doc → will skip
# 2014-12-14 00:00:00: 0 doc → will skip
# 2015-01-13 00:00:00: 0 doc → will skip
# 2015-02-12 00:00:00: 0 doc → will skip
# 2015-03-14 00:00:00: 0 doc → will skip
# 2015-04-13 00:00:00: 0 doc → will skip
# 2015-05-13 00:00:00: 0 doc → will skip
# 2015-06-12 00:00:00: 0 doc → will skip
# 2015-07-12 00:00:00: 0 doc → will skip
# 2015-08-11 00:00:00: 0 doc → will skip
# 2015-09-10 00:00:00: 0 doc → will skip
# 2015-10-10 00:00:00: 0 doc → will skip
# 2015-11-09 00:00:00: 0 doc → will skip
# 2015-12-09 00:00:00: 0 doc → will skip
# 2016-01-08 00:00:00: 0 doc → will skip
# 2016-02-07 00:00:00: 0 doc → will skip
# 2016-03-08 00:00:00: 0 doc → will skip
# 2016-04-07 00:00:00: 0 doc → will skip
# 2016-05-07 00:00:00: 0 doc → will skip
# 2016-06-06 00:00:00: 0 doc → will skip
# 2016-07-06 00:00:00: 0 doc → will skip
# 2016-08-05 00:00:00: 0 doc → will skip
# 2016-09-04 00:00:00: 0 doc → will skip
# 2016-10-04 00:00:00: 0 doc → will skip
# 2016-11-03 00:00:00: 0 doc → will skip
# 2016-12-03 00:00:00: 0 doc → will skip
# 2017-01-02 00:00:00: 0 doc → will skip
# 2017-02-01 00:00:00: 0 doc → will skip
# 2017-03-03 00:00:00: 0 doc → will skip
# 2017-04-02 00:00:00: 0 doc → will skip
# 2017-05-02 00:00:00: 0 doc → will skip
# 2017-06-01 00:00:00: 0 doc → will skip
# 2017-07-01 00:00:00: 0 doc → will skip
# 2017-07-31 00:00:00: 0 doc → will skip
# 2017-08-30 00:00:00: 0 doc → will skip
# 2017-09-29 00:00:00: 0 doc → will skip
# 2017-10-29 00:00:00: 0 doc → will skip
# 2017-11-28 00:00:00: 0 doc → will skip
# 2017-12-28 00:00:00: 0 doc → will skip
# 2018-01-27 00:00:00: 0 doc → will skip
# 2018-02-26 00:00:00: 0 doc → will skip
# 2018-03-28 00:00:00: 0 doc → will skip
# 2018-04-27 00:00:00: 0 doc → will skip
# 2018-05-27 00:00:00: 0 doc → will skip
# 2018-06-26 00:00:00: 0 doc → will skip
# 2018-07-26 00:00:00: 0 doc → will skip
# 2018-08-25 00:00:00: 0 doc → will skip
# 2018-09-24 00:00:00: 0 doc → will skip
# 2018-10-24 00:00:00: 0 doc → will skip
# 2018-11-23 00:00:00: 0 doc → will skip
# 2018-12-23 00:00:00: 0 doc → will skip
# 2019-01-22 00:00:00: 0 doc → will skip
# 2019-02-21 00:00:00: 0 doc → will skip
# 2019-03-23 00:00:00: 0 doc → will skip
# 2019-04-22 00:00:00: 4 doc → will down-tune UMAP (comp=2)
# 2019-05-22 00:00:00: 0 doc → will skip
# 2019-06-21 00:00:00: 1 doc → will skip
# 2019-07-21 00:00:00: 1 doc → will skip
# 2019-08-20 00:00:00: 0 doc → will skip
# 2019-09-19 00:00:00: 0 doc → will skip
# 2019-10-19 00:00:00: 0 doc → will skip
# 2019-11-18 00:00:00: 0 doc → will skip
# 2019-12-18 00:00:00: 1 doc → will skip
# 2020-01-17 00:00:00: 2 doc → will skip
# 2020-03-17 00:00:00: 2 doc → will skip
# 2020-04-16 00:00:00: 6 doc → will down-tune UMAP (comp=4)
# 2020-06-15 00:00:00: 5 doc → will down-tune UMAP (comp=3)

# %% [markdown]
# ### 4. Train topic models

# %%
bertrend.train_topic_models(grouped_data=grouped_data, embedding_model="text-embedding-bge-base-en-v1.5", embeddings=embeddings)
# Out:
# 2025-05-15 10:58:29.248 | INFO     | bertrend.BERTrend:train_topic_models:473 - Training topic model
| INFO     | bertrend.BERTrend:train_topic_models:512 - Saving topic model for period 2020-10-13 00:00:00...
# 2025-05-15 10:58:30,329 - BERTopic - WARNING: You are saving a BERTopic model without explicitly defining an embedding model.If you are using a sentence-transformers model or a HuggingFace model supportedby sentence-transformers, please save the model by using a pointer towards that model.For example, `save_embedding_model='sentence-transformers/all-mpnet-base-v2'`
# 2025-05-15 10:58:30.335 | DEBUG    | bertrend.BERTrend:train_topic_models:520 - Successfully processed period: 2020-10-13 00:00:00
# 2025-05-15 10:58:30.335 | INFO     | bertrend.BERTrend:train_topic_models:473 - Training topic model 23/24...
# 2025-05-15 10:58:30.339 | DEBUG    | bertrend.BERTrend:_train_by_period:242 - Processing period: 2020-11-12 00:00:00
# 2025-05-15 10:58:30.339 | DEBUG    | bertrend.BERTrend:_train_by_period:243 - Number of documents: 419
# 2025-05-15 10:58:30.339 | DEBUG    | bertrend.BERTrend:_train_by_period:379 - Creating topic model...
# 2025-05-15 10:58:30.340 | DEBUG    | bertrend.BERTopicModel:fit:264 - 	Initializing BERTopic model
# 2025-05-15 10:58:30.340 | SUCCESS  | bertrend.BERTopicModel:fit:274 - 	BERTopic model instance created successfully
# 2025-05-15 10:58:30.340 | DEBUG    | bertrend.BERTopicModel:fit:276 - 	Fitting BERTopic model
# 2025-05-15 10:58:30,341 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-15 10:58:30,767 - BERTopic - Dimensionality - Completed ✓
# 2025-05-15 10:58:30,767 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-15 10:58:30,780 - BERTopic - Cluster - Completed ✓
# 2025-05-15 10:58:30,782 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-05-15 10:58:30,812 - BERTopic - Representation - Completed ✓
# 2025-05-15 10:58:30.862 | DEBUG    | bertrend.BERTopicModel:fit:283 - 	Reducing outliers
# 2025-05-15 10:58:30.864 | DEBUG    | bertrend.BERTopicModel:fit:290 - 	Updating topics
# 2025-05-15 10:58:30,864 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# 2025-05-15 10:58:30.887 | SUCCESS  | bertrend.BERTopicModel:fit:312 - 	BERTopic model fitted successfully
# 2025-05-15 10:58:30.888 | DEBUG    | bertrend.BERTrend:_train_by_period:383 - Topic model created successfully
# 2025-05-15 10:58:30.899 | DEBUG    | bertrend.BERTrend:merge_models_with:558 - Merging topic models for timestamps: 2020-10-13 00:00:00 and 2020-11-12 00:00:00
# 2025-05-15 10:58:30.923 | SUCCESS  | bertrend.BERTrend:merge_models_with:626 - Models 2020-11-12 00:00:00 merged successfully with others
# 2025-05-15 10:58:30.923 | INFO     | bertrend.BERTrend:train_topic_models:512 - Saving topic model for period 2020-11-12 00:00:00...
# 2025-05-15 10:58:30,924 - BERTopic - WARNING: You are saving a BERTopic model without explicitly defining an embedding model.If you are using a sentence-transformers model or a HuggingFace model supportedby sentence-transformers, please save the model by using a pointer towards that model.For example, `save_embedding_model='sentence-transformers/all-mpnet-base-v2'`
# 2025-05-15 10:58:30.932 | DEBUG    | bertrend.BERTrend:train_topic_models:520 - Successfully processed period: 2020-11-12 00:00:00
# 2025-05-15 10:58:30.932 | INFO     | bertrend.BERTrend:train_topic_models:473 - Training topic model 24/24...
# 2025-05-15 10:58:30.933 | DEBUG    | bertrend.BERTrend:_train_by_period:242 - Processing period: 2020-12-12 00:00:00
# 2025-05-15 10:58:30.934 | DEBUG    | bertrend.BERTrend:_train_by_period:243 - Number of documents: 55
# 2025-05-15 10:58:30.935 | DEBUG    | bertrend.BERTrend:_train_by_period:379 - Creating topic model...
# 2025-05-15 10:58:30.935 | DEBUG    | bertrend.BERTopicModel:fit:264 - 	Initializing BERTopic model
# 2025-05-15 10:58:30.936 | SUCCESS  | bertrend.BERTopicModel:fit:274 - 	BERTopic model instance created successfully
# 2025-05-15 10:58:30.936 | DEBUG    | bertrend.BERTopicModel:fit:276 - 	Fitting BERTopic model
# 2025-05-15 10:58:30,937 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-15 10:58:30,975 - BERTopic - Dimensionality - Completed ✓
# 2025-05-15 10:58:30,976 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-15 10:58:30,980 - BERTopic - Cluster - Completed ✓
# 2025-05-15 10:58:30,981 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-05-15 10:58:30,988 - BERTopic - Representation - Completed ✓
# 2025-05-15 10:58:30.994 | WARNING  | bertrend.BERTopicModel:fit:280 - 	No outliers to reduce.
# 2025-05-15 10:58:30.994 | DEBUG    | bertrend.BERTopicModel:fit:290 - 	Updating topics
# 2025-05-15 10:58:30,995 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# 2025-05-15 10:58:31.001 | SUCCESS  | bertrend.BERTopicModel:fit:312 - 	BERTopic model fitted successfully
# 2025-05-15 10:58:31.001 | DEBUG    | bertrend.BERTrend:_train_by_period:383 - Topic model created successfully
# 2025-05-15 10:58:31.010 | DEBUG    | bertrend.BERTrend:merge_models_with:558 - Merging topic models for timestamps: 2020-11-12 00:00:00 and 2020-12-12 00:00:00
# 2025-05-15 10:58:31.017 | SUCCESS  | bertrend.BERTrend:merge_models_with:626 - Models 2020-12-12 00:00:00 merged successfully with others
# 2025-05-15 10:58:31.018 | INFO     | bertrend.BERTrend:train_topic_models:512 - Saving topic model for period 2020-12-12 00:00:00...
# 2025-05-15 10:58:31,018 - BERTopic - WARNING: You are saving a BERTopic model without explicitly defining an embedding model.If you are using a sentence-transformers model or a HuggingFace model supportedby sentence-transformers, please save the model by using a pointer towards that model.For example, `save_embedding_model='sentence-transformers/all-mpnet-base-v2'`
# 2025-05-15 10:58:31.022 | DEBUG    | bertrend.BERTrend:train_topic_models:520 - Successfully processed period: 2020-12-12 00:00:00
# 2025-05-15 10:58:31.022 | SUCCESS  | bertrend.BERTrend:train_topic_models:529 - Finished training all topic models

# %% [markdown]
# ### 5. (Optional) Save trained_models

# %%
bertrend.save_model()
# Out:
# 2025-05-15 10:58:31.098 | INFO     | bertrend.BERTrend:save_model:951 - BERTrend model saved to: /Users/cnm13ryan/git/cache/models

# %% [markdown]
# ### 7. Calculate signal popularity

# %%
bertrend.calculate_signal_popularity()

# %%
window_size = 30

# List of strong and weak signals over time
for ts in bertrend.doc_groups.keys():
    print(ts)
    noise_topics_df, weak_signal_topics_df, strong_signal_topics_df = bertrend.classify_signals(window_size, ts)
    if not weak_signal_topics_df.empty:
        print("Weak signals")
        display(weak_signal_topics_df[["Topic","Representation"]].head(5))
    if not strong_signal_topics_df.empty:
        print("Strong signals")
        display(strong_signal_topics_df[["Topic","Representation"]].head(5))
    print()
# Out:
# 2011-08-02 00:00:00
#
# 2012-10-25 00:00:00
#
# 2012-11-24 00:00:00
#
# 2012-12-24 00:00:00
#
# 2013-01-23 00:00:00
#
# 2013-04-23 00:00:00
#
# 2013-09-20 00:00:00
#
# 2013-10-20 00:00:00
#
# 2019-04-22 00:00:00
#
# 2019-06-21 00:00:00
#
# 2019-07-21 00:00:00
#
# 2019-12-18 00:00:00
#
# 2020-01-17 00:00:00
#
# 2020-02-16 00:00:00
#
# 2020-03-17 00:00:00
#
# 2020-04-16 00:00:00
#
# 2020-05-16 00:00:00
#
# 2020-06-15 00:00:00
#
# 2020-07-15 00:00:00
#
# 2020-08-14 00:00:00
#
# 2020-09-13 00:00:00
# Strong signals
#    Topic                                     Representation
# 0      0  wisconsin_underway_minnesota_early_thank_let_v...
# 1      1  thing_terrible_black_jones_tape_vernon_elector...
# 2020-10-13 00:00:00
# Weak signals
#    Topic                                     Representation
# 0      0  evening_updates_bookies_sens_holds_loeffler_pe...
# Strong signals
#    Topic                                     Representation
# 0      1  chris_krebs_secure_security_except_dull_unacco...
# 2020-11-12 00:00:00
# Weak signals
#    Topic                                     Representation
# 0      1  court_merits_texas_its_united_supreme_were_the...
# 2020-12-12 00:00:00
# Strong signals
#    Topic                                     Representation
# 0      1  court_merits_texas_its_united_supreme_were_the...

# %%
# selection of one particular timestamp to look at
selected_timestamp = Timestamp('2017-04-20 00:00:00')
selected_topic_model = bertrend.restore_topic_model(selected_timestamp)

# %% [markdown]
# ### Get topic description

# %%
desc = generate_topic_description(topic_model=selected_topic_model, topic_number=5, filtered_docs=df, language_code="en")
# Out:
# 2025-05-15 10:58:31.324 | ERROR    | bertrend.topic_analysis.topic_description:generate_topic_description:51 - generate_topic_description: topic_model is None

# %%
desc.title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 desc.title
#
# AttributeError: 'NoneType' object has no attribute 'title'

# %%
desc.description

# %% [markdown]
# ### Get topic analysis

# %%
summary, analysis, formatted_html = analyze_signal(bertrend, 1, selected_timestamp)

# %%
from IPython.display import display, HTML
display(HTML(formatted_html))

# %% [markdown]
# ## Using BERTrend for prospective analysis

# %% [markdown]
# In the case of a **prospective trend analysis task**, the goal is to **forecast future** developments or outcomes based on current data and trends, enabling organizations to make informed decisions, allocate resources effectively, and strategize for upcoming challenges or opportunities.

# %% [markdown]
# In this example, we are going to simulate a prospective task:
# - we simulate new data coming in
# - for each new data, we will compute the new topic model, merge it to previous one and detect at each iteration strong and weak signals

# %%
MY_DATA_DIR = Path("/DSIA/nlp/bertrend/data") / "feeds/feed_sobriete"

input_data = [
    MY_DATA_DIR / "2024-12-30_feed_sobriete.jsonl",
    MY_DATA_DIR / "2025-01-06_feed_sobriete.jsonl",
    MY_DATA_DIR / "2025-01-20_feed_sobriete.jsonl",
]

window_size = 7

# %%
embedding_service_cfg = {"local": False, "url":"https://10.132.5.44:6464", "client_secret":client_secret}

embedding_service = EmbeddingService(**embedding_service_cfg)
embedding_model_name = embedding_service.embedding_model_name

# %%
BERTREND_MODELS_PATH = MODELS_DIR / "sobriete_models"

# %%
def process_new_data(data_slice_path: Path, timestamp: pd.Timestamp):
    logger.debug(f"Processing new data: {data_slice_path}")

    # Restore previous models
    try:
        bertrend = BERTrend.restore_model(BERTREND_MODELS_PATH)
    except:
        logger.warning("Cannot restore previous models, creating new one")
        bertrend = BERTrend(topic_model=BERTopicModel())

    # Read data
    df = load_data(data_slice_path, language="French")
    df = split_data(df)
    text = df[TEXT_COLUMN]

    # Embed new data
    embeddings, token_strings, token_embeddings = embedding_service.embed(
                texts=text,
    )

    # Create topic model for new data
    bertrend.train_topic_models({timestamp: df}, embeddings=embeddings, embedding_model=embedding_model_name)
    
    logger.info(f"BERTrend processed {len(bertrend.doc_groups)} time periods")
    
    # Save models
    bertrend.save_model(models_path=BERTREND_MODELS_PATH)

    
    if len(bertrend.doc_groups)<2:
        return None
        
    # Compute popularities
    bertrend.calculate_signal_popularity()
    
    # classify last signals
    noise_topics_df, weak_signal_topics_df, strong_signal_topics_df = bertrend.classify_signals(window_size, timestamp)
    # TODO: save dfs

    if weak_signal_topics_df.empty:
        return None
        
    wt = weak_signal_topics_df['Topic']
    logger.info(f"Weak topics: {wt}")
    wt_list = []
    for topic in wt:
        topic_model = bertrend.restore_topic_model(timestamp)
        desc = generate_topic_description(topic_model=topic_model, topic_number=topic, filtered_docs=df, language_code="fr")
        wt_list.append({"timestamp": timestamp, "topic": topic, "title": desc.title, "description": desc.description})

    return pd.DataFrame(wt_list)

# %%
for data_file in input_data:
    timestamp = pd.Timestamp(data_file.name.split('_')[0])
    display(process_new_data(data_file, timestamp))

# %% [markdown]
# ## 5. Evaluation & Visualization <a id='eval'></a>
# Assess topic coherence, diversity, and trend detection precision.

# %% [markdown]
# ## 6. Next Steps & References <a id='next'></a>
# - Extend to streaming data via `BERTrendStream`.
# - See *Topic Modeling and Trend Detection with BERTopic* (Grootendorst, 2022).
